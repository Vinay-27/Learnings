# %%
corpus="Ihi this vinay . doing nlp, working at inf'osys! playing badmintion, enjoying "

# %%
from nltk.tokenize import sent_tokenize
sent_tokenize(corpus)
# Out:
# ['Ihi this vinay .',
#  "doing nlp, working at inf'osys!",
#  'playing badmintion, enjoying']

# %%
documents=sent_tokenize(corpus)

for sentence in documents:
    print(sentence)
# Out:
# Ihi this vinay .
# doing nlp, working at inf'osys!
# playing badmintion, enjoying

# %%
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['Ihi',
#  'this',
#  'vinay',
#  '.',
#  'doing',
#  'nlp',
#  ',',
#  'working',
#  'at',
#  "inf'osys",
#  '!',
#  'playing',
#  'badmintion',
#  ',',
#  'enjoying']

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Ihi',
#  'this',
#  'vinay',
#  '.',
#  'doing',
#  'nlp',
#  ',',
#  'working',
#  'at',
#  'inf',
#  "'",
#  'osys',
#  '!',
#  'playing',
#  'badmintion',
#  ',',
#  'enjoying']
